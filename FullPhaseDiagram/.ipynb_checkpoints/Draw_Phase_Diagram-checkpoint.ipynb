# %%
import matplotlib.pylab as plt
import numpy as np
import glob
from scipy.interpolate import UnivariateSpline
import shapely
from shapely.geometry import LineString, Point
from scipy.interpolate import interp1d
# %config InlineBackend.figure_format = 'retina'
# !mkdir -p figures tables

# %%
def intersection_point(gibbs_line1,gibbs_line2):
    line1 = LineString(gibbs_line1)
    line2 = LineString(gibbs_line2)
    int_pt = line2.intersection(line1)
    print(int_pt.geom_type,int_pt)
    if int_pt.geom_type == 'Point':
        point_of_intersection = int_pt.x, int_pt.y
    else:
        int_pt=int_pt[0]
        point_of_intersection = int_pt.x, int_pt.y

    return point_of_intersection

# %%
def load_gibbs(fold,sort='P'):
    PT_IceIh_Liquid=glob.glob(fold+'/*_*_*')

    PT_IceIh_Liquid=[[int(a.split('/')[-1].split('_')[0]),float(a.split('/')[-1].split('_')[1]),float(a.split('/')[-1].split('_')[2])]  for a in PT_IceIh_Liquid]
    PT_IceIh_Liquid=np.array(PT_IceIh_Liquid)
    PT_IceIh_Liquid=PT_IceIh_Liquid[np.argsort(PT_IceIh_Liquid[:,0])]#[:,1:]
    index_0=np.where(PT_IceIh_Liquid[:,0]==0)[0][0]
    
    PT_IceIh_Liquid=np.concatenate((PT_IceIh_Liquid[index_0::-4][::-1],PT_IceIh_Liquid[index_0::4][1:]),axis=0)
    PT_IceIh_Liquid=PT_IceIh_Liquid[:,1:]
    return PT_IceIh_Liquid

# %%
color_dict={'pd': 'k','vega1':'r','vega2':'tab:brown','IceIh':'b','IceII':'g','IceIII':'c','IceV':'y','IceVI':'m'}

IceIII_Liquid = np.loadtxt('../IceIII_Liquidv2/5-BiasedCoexistence/P_T.dat')
IceV_Liquid = np.loadtxt('../IceV_Liquid/4-BiasedCoexistencev2/P_T.dat')
IceVI_Liquid = np.loadtxt('../IceVI_Liquid/5-BiasedCoexistencev2/P_T.dat')
IceIh_Liquid = np.loadtxt('../IceIh_Liquid/3-BiasedCoexistencev2/P_T.dat')
IceII_Liquid = np.loadtxt('../IceII_Liquid/5-BiasedCoexistence/P_T.dat')

MeltingPoints=dict()
MeltingPoints['IceIh_Liquid']=np.loadtxt('../IceIh_Liquid/3-BiasedCoexistencev2/P_T.dat')
MeltingPoints['IceII_Liquid']=np.loadtxt('../IceII_Liquid/5-BiasedCoexistence/P_T.dat')
MeltingPoints['IceIII_Liquid']=np.loadtxt('../IceIII_Liquidv2/5-BiasedCoexistence/P_T.dat')
MeltingPoints['IceV_Liquid']=np.loadtxt('../IceV_Liquid/4-BiasedCoexistencev2/P_T.dat')
MeltingPoints['IceVI_Liquid']=np.loadtxt('../IceVI_Liquid/5-BiasedCoexistencev2/P_T.dat')

GibbsLines=dict()
GibbsLines['IceIh_Liquid']=load_gibbs('../Gibbs_Duhem_Simulations/IceIh_Liquid/*/')
GibbsLines['IceIII_Liquid']=load_gibbs('../Gibbs_Duhem_Simulations/IceIII_Liquid/4000.0atm_262.9K/')
GibbsLines['IceVI_Liquid']=load_gibbs('../Gibbs_Duhem_Simulations/IceVI_Liquid/*/')
GibbsLines['IceV_Liquid']=load_gibbs('../Gibbs_Duhem_Simulations/IceV_Liquid/7000.0atm_258.4K/')
GibbsLines['IceII_Liquid']=load_gibbs('../Gibbs_Duhem_Simulations/IceII_Liquid/*/')
GibbsLines['IceII_IceIh']=load_gibbs('../Gibbs_Duhem_Simulations/IceII_IceIh/*/')
GibbsLines['IceVI_IceV']=load_gibbs('../Gibbs_Duhem_Simulations/IceVI_IceV/*/',sort='T')
GibbsLines['IceV_IceIII']=load_gibbs('../Gibbs_Duhem_Simulations/IceV_IceIII/*/',sort='T')
GibbsLines['IceIh_IceIII']=load_gibbs('../Gibbs_Duhem_Simulations/IceIh_IceIII/*/',sort='T')
GibbsLines['IceII_IceIII']=load_gibbs('../Gibbs_Duhem_Simulations/IceII_IceIII/*/',sort='P')
GibbsLines['IceII_IceV']=load_gibbs('../Gibbs_Duhem_Simulations/IceII_IceV/*/',sort='T')
GibbsLines['IceII_IceVI']=load_gibbs('../Gibbs_Duhem_Simulations/IceII_IceVI/*/',sort='T')

GD_IceIh_Liquid=load_gibbs('../Gibbs_Duhem_Simulations/IceIh_Liquid/*/')
GD_IceIII_Liquid=load_gibbs('../Gibbs_Duhem_Simulations/IceIII_Liquid/4000.0atm_262.9K/')
GD_IceVI_Liquid=load_gibbs('../Gibbs_Duhem_Simulations/IceVI_Liquid/*/')
GD_IceV_Liquid=load_gibbs('../Gibbs_Duhem_Simulations/IceV_Liquid/7000.0atm_258.4K/')
GD_IceII_Liquid=load_gibbs('../Gibbs_Duhem_Simulations/IceII_Liquid/*/')
GD_IceII_IceIh=load_gibbs('../Gibbs_Duhem_Simulations/IceII_IceIh/*/')
GD_IceVI_IceV=load_gibbs('../Gibbs_Duhem_Simulations/IceVI_IceV/*/',sort='T')
GD_IceV_IceIII=load_gibbs('../Gibbs_Duhem_Simulations/IceV_IceIII/*/',sort='T')
GD_IceIh_IceIII=load_gibbs('../Gibbs_Duhem_Simulations/IceIh_IceIII/*/',sort='T')
GD_IceII_IceIII=load_gibbs('../Gibbs_Duhem_Simulations/IceII_IceIII/*/',sort='P')
GD_IceII_IceV=load_gibbs('../Gibbs_Duhem_Simulations/IceII_IceV/*/',sort='T')
GD_IceII_IceVI=load_gibbs('../Gibbs_Duhem_Simulations/IceII_IceVI/*/',sort='T')


tip4p_vega_data=np.genfromtxt('../ReferenceData/tip4p_iceIh+III_liquid_FE.dat')
tip4p_vega_data[:,1]=tip4p_vega_data[:,1]*10*0.986923
tip4p_vega_data2=np.genfromtxt('../ReferenceData/tip4p_iceIh+III_liquid_DC.dat')
tip4p_vega_data2[:,1]=tip4p_vega_data2[:,1]*1000*0.986923

# Ice_III_Liquid_spl = UnivariateSpline(IceIII_Liquid[:,0], IceIII_Liquid[:,1])
# Ice_Ih_Liquid_spl = UnivariateSpline(IceIh_Liquid[:,0], IceIh_Liquid[:,1])
# IceVI_Liquid_spl = UnivariateSpline(IceVI_Liquid[:,0], IceVI_Liquid[:,1])
# IceV_Liquid_spl = UnivariateSpline(IceV_Liquid[:,0], IceV_Liquid[:,1])

# Ice_III_Liquid_spl.set_smoothing_factor(0.05)
# Ice_Ih_Liquid_spl.set_smoothing_factor(0.05)

# %% [markdown]
# ### Determine intersection points

# %%
trip_pts={}
trip_pts['Liquid IceIII IceV']= intersection_point(GD_IceIII_Liquid,GD_IceV_Liquid)
trip_pts['Liquid IceIh IceII']= intersection_point(GD_IceIh_Liquid,GD_IceII_Liquid)
trip_pts['Liquid IceV IceVI']= intersection_point(GD_IceV_Liquid,GD_IceVI_Liquid)
trip_pts['Liquid IceIII IceIh']= intersection_point(GD_IceIII_Liquid,GD_IceIh_Liquid)
trip_pts['IceII IceIh IceIII']= intersection_point(GD_IceII_IceIh,GD_IceIh_IceIII)
trip_pts['IceII IceIII IceV']= intersection_point(GD_IceII_IceIII,GD_IceV_IceIII)
trip_pts['IceII IceV IceVI']= intersection_point(GD_IceII_IceV,GD_IceVI_IceV)


with open('triple_points.dat','w') as fp:
    for key in trip_pts:
        line='{}\t{:.2f}\t{:.2f}\n'.format(key,trip_pts[key][0],trip_pts[key][1])
        fp.write(line)
# !cat triple_points.dat
# Out:
# Point POINT (261.4723529411765 7816.176470588237)
# Point POINT (240.098418568954 2153.481144247516)
# Point POINT (263.2669918699187 8373.983739837393)
# Point POINT (252.71527080413233 1412.2142056579926)
# Point POINT (98.17930232558139 2043.8189534883722)
# Point POINT (131.78753701895423 7108.262765352666)
# Point POINT (80.48914890864575 8241.167404261925)
# Liquid IceIII IceV	261.47	7816.18
# Liquid IceIh IceII	240.10	2153.48
# Liquid IceV IceVI	263.27	8373.98
# Liquid IceIII IceIh	252.72	1412.21
# IceII IceIh IceIII	98.18	2043.82
# IceII IceIII IceV	131.79	7108.26
# IceII IceV IceVI	80.49	8241.17

# %%
plt.figure(figsize=(4.5,3.5))
plt.scatter(tip4p_vega_data[:,0],tip4p_vega_data[:,1],label='Vega TIP4P/ice/free',s=1,color='k')
plt.scatter(tip4p_vega_data2[:,0],tip4p_vega_data2[:,1],label='Vega TIP4P/ice/coex',s=1,color='g')

t_range=np.linspace(210,270,200)
p_range_IceIII_Liquid = np.linspace(1750,7000,200)
p_range_IceIh_Liquid = np.linspace(0,3000,200)


#idx = np.argwhere(np.diff(np.sign(Ice_III_Liquid_spl(p_range_IceIII_Liquid) - Ice_Ih_Liquid_spl(p_range_IceIh_Liquid)))).flatten()[0]
#p_range=np.linspace(0,9000,2000)
#P=p_range[np.argwhere(np.diff(np.sign(Ice_III_Liquid_spl(p_range) - Ice_Ih_Liquid_spl(p_range)))).flatten()[0]]
# print(P)

#Splines
#plt.scatter(IceIh_Liquid[:,1],IceIh_Liquid[:,0],color='r')


plt.plot(GD_IceIII_Liquid[:,0],GD_IceIII_Liquid[:,1],color='b',label='Gibbs-Duhem')

plt.plot(GD_IceIh_Liquid[:,0],GD_IceIh_Liquid[:,1],color=color_dict['IceIh'])
plt.plot(GD_IceIII_Liquid[:,0],GD_IceIII_Liquid[:,1],color=color_dict['IceIII'])
plt.plot(GD_IceVI_Liquid[:,0],GD_IceVI_Liquid[:,1],color=color_dict['IceVI'])
plt.plot(GD_IceV_Liquid[:,0],GD_IceV_Liquid[:,1],color=color_dict['IceV'])
plt.plot(GD_IceII_Liquid[:,0],GD_IceII_Liquid[:,1],color=color_dict['IceII'])
plt.plot(GD_IceII_IceIh[:,0],GD_IceII_IceIh[:,1],color=color_dict['IceIh'])
plt.plot(GD_IceVI_IceV[:,0],GD_IceVI_IceV[:,1],color=color_dict['IceVI'])
plt.plot(GD_IceV_IceIII[:,0],GD_IceV_IceIII[:,1],color=color_dict['IceV'])
plt.plot(GD_IceIh_IceIII[:,0],GD_IceIh_IceIII[:,1],color=color_dict['IceIh'])
plt.plot(GD_IceII_IceIII[:,0],GD_IceII_IceIII[:,1],color=color_dict['IceII'])
plt.plot(GD_IceII_IceV[:,0],GD_IceII_IceV[:,1],color=color_dict['IceII'])
# plt.plot(GD_IceII_IceVI[:,0],GD_IceII_IceVI[:,1],color=color_dict['IceII'])

plt.scatter(IceVI_Liquid[:,1],IceVI_Liquid[:,0],color=color_dict['IceVI'],marker='x', s=20)
plt.scatter(IceV_Liquid[:,1],IceV_Liquid[:,0],color=color_dict['IceV'],marker='x', s=20)
plt.scatter(IceIh_Liquid[:,1],IceIh_Liquid[:,0],color=color_dict['IceIh'],marker='x', s=20)
plt.scatter(IceII_Liquid[:,1],IceII_Liquid[:,0],color=color_dict['IceII'],marker='x', s=20)
plt.scatter(IceIII_Liquid[:,1],IceIII_Liquid[:,0],color=color_dict['IceIII'],marker='x', s=20)

#plt.scatter(IceIh_Liquid[idx:,1],IceIh_Liquid[:,0],ls=)

#plt.plot(Ice_Ih_Liquid_spl(p_range_IceIh_Liquid[p_range_IceIh_Liquid<P]),p_range_IceIh_Liquid[p_range_IceIh_Liquid<P],color='r')
#plt.plot(Ice_Ih_Liquid_spl(p_range_IceIh_Liquid[p_range_IceIh_Liquid>P]),p_range_IceIh_Liquid[p_range_IceIh_Liquid>P],ls='--',color='r')

#plt.xlim([0,290])
#plt.ylim([-3000,10000])
#plt.xlim([0,300])

plt.annotate('Ih',(250,-500),color=color_dict['IceIh'])
plt.annotate('Liquid',(280,2000))
plt.annotate('III',(245,3000),color=color_dict['IceIII'])
plt.annotate('V',(235,6000),color=color_dict['IceV'])
plt.annotate('II',(202,3150),color=color_dict['IceII'])
plt.annotate('VI',(255,10000),color=color_dict['IceVI'])
plt.ylabel('P/atm')
plt.xlabel('T/K')

plt.legend()

# %%
#Ih-Liq
St_GD_IceIh_Liquid=GD_IceIh_Liquid[GD_IceIh_Liquid[:,1]>=0]
St_GD_IceIh_Liquid=St_GD_IceIh_Liquid[St_GD_IceIh_Liquid[:,1]<=trip_pts['Liquid IceIII IceIh'][1]]
St_GD_IceIh_Liquid=np.vstack((St_GD_IceIh_Liquid,trip_pts['Liquid IceIII IceIh']))

#III-Liq
St_GD_IceIII_Liquid=GD_IceIII_Liquid[GD_IceIII_Liquid[:,1]>=trip_pts['Liquid IceIII IceIh'][1]]
St_GD_IceIII_Liquid=St_GD_IceIII_Liquid[St_GD_IceIII_Liquid[:,1]<=trip_pts['Liquid IceIII IceV'][1]]
St_GD_IceIII_Liquid=np.vstack((trip_pts['Liquid IceIII IceIh'],St_GD_IceIII_Liquid))

#V-Liq
St_GD_IceV_Liquid=GD_IceV_Liquid[GD_IceV_Liquid[:,1]>=trip_pts['Liquid IceIII IceV'][1]]
St_GD_IceV_Liquid=St_GD_IceV_Liquid[St_GD_IceV_Liquid[:,1]<=trip_pts['Liquid IceV IceVI'][1]]
St_GD_IceV_Liquid=np.vstack((St_GD_IceV_Liquid,trip_pts['Liquid IceIII IceV']))
St_GD_IceV_Liquid=np.vstack((trip_pts['Liquid IceV IceVI'],St_GD_IceV_Liquid))


#VI-Liq
St_GD_IceVI_Liquid=GD_IceVI_Liquid[GD_IceVI_Liquid[:,1]>=trip_pts['Liquid IceV IceVI'][1]]
St_GD_IceVI_Liquid=np.vstack((trip_pts['Liquid IceV IceVI'],St_GD_IceVI_Liquid))

#Ih-III
St_GD_IceIh_IceIII=GD_IceIh_IceIII[GD_IceIh_IceIII[:,0]<=trip_pts['Liquid IceIII IceIh'][0]]
St_GD_IceIh_IceIII=St_GD_IceIh_IceIII[St_GD_IceIh_IceIII[:,0]>=trip_pts['IceII IceIh IceIII'][0]]
St_GD_IceIh_IceIII=np.vstack((trip_pts['IceII IceIh IceIII'],St_GD_IceIh_IceIII))
St_GD_IceIh_IceIII=np.vstack((St_GD_IceIh_IceIII,trip_pts['Liquid IceIII IceIh'],))

#Ih-II
St_GD_IceII_IceIh=GD_IceII_IceIh[GD_IceII_IceIh[:,0]<=trip_pts['IceII IceIh IceIII'][0]]
St_GD_IceII_IceIh=np.vstack((St_GD_IceII_IceIh,trip_pts['IceII IceIh IceIII'],))

#II-III
St_GD_IceII_IceIII=GD_IceII_IceIII[GD_IceII_IceIII[:,1]>=trip_pts['IceII IceIh IceIII'][1]]
St_GD_IceII_IceIII=St_GD_IceII_IceIII[St_GD_IceII_IceIII[:,1]<=trip_pts['IceII IceIII IceV'][1]]
St_GD_IceII_IceIII=np.vstack((trip_pts['IceII IceIh IceIII'],St_GD_IceII_IceIII))
St_GD_IceII_IceIII=np.vstack((St_GD_IceII_IceIII,trip_pts['IceII IceIII IceV']))

#VI-V
St_GD_IceVI_IceV=GD_IceVI_IceV[GD_IceVI_IceV[:,0]<=trip_pts['Liquid IceV IceVI'][0]]
St_GD_IceVI_IceV=St_GD_IceVI_IceV[St_GD_IceVI_IceV[:,0]>=trip_pts['IceII IceV IceVI'][0]]
St_GD_IceVI_IceV=np.vstack((trip_pts['IceII IceV IceVI'],St_GD_IceVI_IceV))
St_GD_IceVI_IceV=np.vstack((St_GD_IceVI_IceV,trip_pts['Liquid IceV IceVI']))

#II-V
St_GD_IceII_IceV=GD_IceII_IceV[GD_IceII_IceV[:,0]<=trip_pts['IceII IceIII IceV'][0]]
St_GD_IceII_IceV=St_GD_IceII_IceV[St_GD_IceII_IceV[:,0]>=trip_pts['IceII IceV IceVI'][0]]
St_GD_IceII_IceV=np.vstack((St_GD_IceII_IceV,trip_pts['IceII IceV IceVI']))
St_GD_IceII_IceV=np.vstack((trip_pts['IceII IceIII IceV'],St_GD_IceII_IceV))

#II-VI
St_GD_IceII_IceVI=GD_IceII_IceVI[GD_IceII_IceVI[:,0]<=trip_pts['IceII IceV IceVI'][0]]
St_GD_IceII_IceVI=np.vstack((St_GD_IceII_IceVI,trip_pts['IceII IceV IceVI']))

#V-III
St_GD_IceV_IceIII=GD_IceV_IceIII[GD_IceV_IceIII[:,0]<=trip_pts['Liquid IceIII IceV'][0]]
St_GD_IceV_IceIII=St_GD_IceV_IceIII[St_GD_IceV_IceIII[:,0]>=trip_pts['IceII IceIII IceV'][0]]
St_GD_IceV_IceIII=np.vstack((trip_pts['IceII IceIII IceV'],St_GD_IceV_IceIII))


#II-Ih
#St_GD_IceV_IceIII=GD_IceV_IceIII[GD_IceV_IceIII[:,0]<=trip_pts['Liquid IceIII IceV'][0]]
#St_GD_IceV_IceIII=St_GD_IceV_IceIII[St_GD_IceV_IceIII[:,0]>=trip_pts['IceII IceIII IceV'][0]]
#St_GD_IceV_IceIII=np.vstack((trip_pts['IceII IceIII IceV'],St_GD_IceV_IceIII))

# %%
fig=plt.figure(figsize=(3.4,2.5))
plt.plot(St_GD_IceIh_Liquid[:,0],St_GD_IceIh_Liquid[:,1],color=color_dict['pd'],zorder=1,label='This work')
plt.plot(St_GD_IceIII_Liquid[:,0],St_GD_IceIII_Liquid[:,1],color=color_dict['pd'],zorder=1)
plt.plot(St_GD_IceV_Liquid[:,0],St_GD_IceV_Liquid[:,1],color=color_dict['pd'],zorder=1)
plt.plot(St_GD_IceVI_Liquid[:,0],St_GD_IceVI_Liquid[:,1],color=color_dict['pd'],zorder=1)
plt.plot(St_GD_IceII_IceIh[:,0],St_GD_IceII_IceIh[:,1],color=color_dict['pd'],zorder=1)

plt.plot(St_GD_IceIh_IceIII[:,0],St_GD_IceIh_IceIII[:,1],color=color_dict['pd'],zorder=1)
plt.plot(St_GD_IceII_IceIII[:,0],St_GD_IceII_IceIII[:,1],color=color_dict['pd'],zorder=1)
plt.plot(St_GD_IceVI_IceV[:,0],St_GD_IceVI_IceV[:,1],color=color_dict['pd'],zorder=1)
plt.plot(St_GD_IceII_IceV[:,0],St_GD_IceII_IceV[:,1],color=color_dict['pd'],zorder=1)
plt.plot(St_GD_IceII_IceVI[:,0],St_GD_IceII_IceVI[:,1],color=color_dict['pd'],zorder=1)
plt.plot(St_GD_IceV_IceIII[:,0],St_GD_IceV_IceIII[:,1],color=color_dict['pd'],zorder=1)
plt.plot(St_GD_IceV_IceIII[:,0],St_GD_IceV_IceIII[:,1],color=color_dict['pd'],zorder=1)


plt.scatter(tip4p_vega_data[:,0],tip4p_vega_data[:,1],label='Vega TIP4P/ice/free',s=1,color=color_dict['vega1'],zorder=2)
plt.scatter(tip4p_vega_data2[:,0],tip4p_vega_data2[:,1],label='Vega TIP4P/ice/coex',s=1,color=color_dict['vega2'],zorder=2)

plt.scatter(IceVI_Liquid[:,1],IceVI_Liquid[:,0],color=color_dict['IceVI'],marker='x', s=30,zorder=3)
plt.scatter(IceV_Liquid[:,1],IceV_Liquid[:,0],color=color_dict['IceV'],marker='x', s=30,zorder=3)
plt.scatter(IceIh_Liquid[:,1],IceIh_Liquid[:,0],color=color_dict['IceIh'],marker='x', s=30,zorder=3)
plt.scatter(IceII_Liquid[:,1],IceII_Liquid[:,0],color=color_dict['IceII'],marker='x', s=30,zorder=3)
plt.scatter(IceIII_Liquid[:,1],IceIII_Liquid[:,0],color=color_dict['IceIII'],marker='x', s=30,zorder=3)
plt.xlim([0,300])
plt.annotate('Ih',(100,-0),color=color_dict['IceIh'])
plt.annotate('Liq.',(270,2000))
plt.annotate('III',(150,3000),color=color_dict['IceIII'])
plt.annotate('V',(160,7500),color=color_dict['IceV'])
plt.annotate('II',(60,3150),color=color_dict['IceII'])
plt.annotate('VI',(240,10000),color=color_dict['IceVI'])
plt.ylabel('P/atm')
plt.xlabel('T/K')
plt.legend(prop={'size': 7},loc=2)
plt.xlim(left=50)
plt.ylim(top=12500)

plt.tight_layout()
plt.savefig('figures/PhaseDiagram.png',dpi=300)

# %% [markdown]
# ## Store latex tables

# %% [markdown]
# ### Triple points

# %%
with open('tables/triple_points.tex','w') as fp:
    fp.write('\\begin{tabular}{lrr}\n\\hline\\hline\n')
    fp.write('&P/atm&T/K\\\\\n\\hline\n')
    for key in trip_pts:
        line='{}&{:.0f}&{:.2f}\\\\\n'.format('-'.join(key.split()),trip_pts[key][1],trip_pts[key][0])
        fp.write(line)
    fp.write('\\hline\\hline\n\end{tabular}')
# !cat triple_points.tex
# Out:
# \begin{tabular}{lrr}
# \hline\hline
# &P/atm&T/K\\
# \hline
# IceIh-Liquid&221&3000.00\\
# IceII-Liquid&240&2000.00\\
# IceIII-Liquid&262&8000.00\\
# IceV-Liquid&262&8000.00\\
# IceVI-Liquid&287&12000.00\\
# \hline\hline
# \end{tabular}

# %% [markdown]
# ### Melting points

# %%
with open('tables/MeltingPoints.tex','w') as fp:
    fp.write('\\begin{tabular}{lrrl}\n\\hline\\hline\n')
    fp.write('&P/atm&T/K\\\\\n\\hline\n')
    for key in MeltingPoints.keys():
        print(key)
        line=''
        for i in range(len(MeltingPoints[key])):
            line+='{}&{:.0f}&{}\\\\\n'.format('-'.join(key.split('_')),MeltingPoints[key][i][0],MeltingPoints[key][i][1])
        fp.write(line+'\\hline\n')
    fp.write('\\hline\\hline\n\end{tabular}')
# !cat MeltingPoints.tex
# Out:
# IceIh_Liquid
# IceII_Liquid
# IceIII_Liquid
# IceV_Liquid
# IceVI_Liquid
# \begin{tabular}{lrr}
# \hline\hline
# &P/atm&T/K\\
# \hline
# IceIh-Liquid&0&269.1\\
# IceIh-Liquid&1000&258.1\\
# IceIh-Liquid&2000&244.5\\
# IceIh-Liquid&3000&220.6\\
# \hline
# IceII-Liquid&1000&229.6\\
# IceII-Liquid&2000&240.0\\
# \hline
# IceIII-Liquid&2000&257.1\\
# IceIII-Liquid&4000&262.9\\
# IceIII-Liquid&6000&265.4\\
# IceIII-Liquid&8000&261.9\\
# \hline
# IceV-Liquid&4000&241.1\\
# IceV-Liquid&6000&254.0\\
# IceV-Liquid&7000&258.4\\
# IceV-Liquid&8000&262.4\\
# \hline
# IceVI-Liquid&8000&259.2\\
# IceVI-Liquid&9000&266.6\\
# IceVI-Liquid&10000&274.8\\
# IceVI-Liquid&12000&286.9\\
# \hline
# \hline\hline
# \end{tabular}
