# %% [markdown]
# # Distribution of order parameter

# %%
import numpy as np, glob
import matplotlib.pylab as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
# Out:
# /var/folders/gk/bdqkskqj2fv8dk9kgrxm5psh0000gn/T/ipykernel_40220/1018117210.py:4: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('retina')

# %%
ice='IceII'

# %% [markdown]
# ### Overlap between distributions

# %%
data=np.loadtxt('results.txt')

plt.figure(figsize=(3.4,2))
plt.plot(data[:,0],data[:,1])
plt.xlabel(r'$\sigma$')
plt.ylabel('Overlap')
plt.tight_layout()

# %%
sigma_min=data[data[:,1]==min(data[:,1])][0][0]
print('Minimum overlap for sigma = {}'.format(sigma_min))
# Out:
# Minimum overlap for sigma = 0.065

# %% [markdown]
# ### Distributions

# %%
hist_liquid = np.loadtxt('Liquid/histo')
hist_IceIII = np.loadtxt('IceIII/histo')

# %%
plt.figure(figsize=(3.4,2))
plt.plot(hist_IceIII[:,0],hist_IceIII[:,1])
plt.plot(hist_liquid[:,0],hist_liquid[:,1])
plt.xlim([0.3,1.3])
plt.annotate(r'$\sigma={}$'.format(sigma_min),(0.4,10))

diff_val = np.abs(hist_liquid[:,1]-hist_IceIII[:,1])
diff_bin = hist_liquid[:,0]
diff_val = diff_val[(diff_bin>0.65) * (diff_bin<1.05)]
diff_bin = diff_bin[(diff_bin>0.65) * (diff_bin<1.05)]

min_order= diff_bin[diff_val.min()==diff_val]
plt.axvline(x=min_order, color='k', linestyle='--')

# %%
print('Liquid max:', hist_liquid[hist_liquid[:,1]==hist_liquid[:,1].max()][0][0])
# Out:
# Liquid max: 0.6

# %%
print('IceIII max:', hist_IceIII[hist_IceIII[:,1]==hist_IceIII[:,1].max()][0][0])
# Out:
# IceIII max: 0.955

# %%
print('Midpoint between distribitions:', min_order[0])
# Out:
# Midpoint between distribitions: 1.0475

# %% [markdown]
# ## Effect of pressure on overlap

# %%
bars=set()
#overlaps=[]
for f in glob.glob('overlap*'):
    #try:
    data=np.loadtxt(f)
    #except:
     #   continue
    sigma_min=data[data[:,1]==min(data[:,1])][0][0]
    bars.add((f.split('/')[-1].replace('overlap_','').replace('.dat',''),sigma_min))
    print(f,sigma_min)
    #overlaps.append()
    plt.plot(data[:,0],data[:,1])
plt.ylim([0,0.1])
# Out:
# overlap_5000bar.dat 0.0625
# overlap_4000bar.dat 0.0625
# overlap_3000bar.dat 0.065
# overlap_2500bar.dat 0.065
# (0.0, 0.1)

# %%
print(bars)
hist_liquid = np.loadtxt('Liquid/histo')
hist_IceIII = np.loadtxt('IceIII/histo')
# Out:
# {('3000bar', 0.065), ('5000bar', 0.0625), ('2500bar', 0.065), ('4000bar', 0.0625)}

# %%
def remove_0(hist):
    return hist[hist[:,1]>0.001]

# %%
#Final choice
sig=0.0625

colors=['r','k','g','b']
means=[]
for i, bar in enumerate(bars):
    #hist_liquid = np.loadtxt('Liquid_{}/Histo'.format(bar[0]))
    #hist_IceIII = np.loadtxt('IceIII_{}/Histo_{:.4}'.format(bar[0]))

    
    hist_IceIII=np.loadtxt('IceIII_{}/Histo_{:.4f}'.format(bar[0],sig))
    hist_Liquid=np.loadtxt('Liquid_{}/Histo_{:.4f}'.format(bar[0],sig))
    diff_val = np.abs(hist_Liquid[:,1]-hist_IceIII[:,1])
    diff_bin = hist_liquid[:,0]
    diff_val = diff_val[(diff_bin>0.5) * (diff_bin<1.0)]
    diff_bin = diff_bin[(diff_bin>0.5) * (diff_bin<1.0)]

    hist_IceIII=remove_0(hist_IceIII)
    hist_Liquid=remove_0(hist_Liquid)
    print('IceIII_{}/Histo_{:.4f}'.format(bar[0],sig))
    print('Liquid max:', hist_Liquid[hist_Liquid[:,1]==hist_Liquid[:,1].max()][0][0])
    print('IceIII max:', hist_IceIII[hist_IceIII[:,1]==hist_IceIII[:,1].max()][0][0])
    min_order= diff_bin[diff_val.min()==diff_val]
    print('Midpoint between distribitions:', min_order[0])
    plt.plot(hist_IceIII[:,0],hist_IceIII[:,1],color=colors[i],label=bar[0])
    plt.plot(hist_Liquid[:,0],hist_Liquid[:,1],color=colors[i])
    means.append([hist_Liquid[hist_Liquid[:,1]==hist_Liquid[:,1].max()][0][0], hist_IceIII[hist_IceIII[:,1]==hist_IceIII[:,1].max()][0][0],min_order[0]])

plt.xlim([0.2,1.2])
means=np.mean(means,axis=0)
print('Liquid max: {:.3f}'.format(means[0]))
print('IceIII max: {:.3f}'.format(means[1]))
print('Midpoint: {:.3f}'.format(means[2]))

dist=0.25*(means[1]-means[0])
plt.axvline(x=means[2],ls='--',color='k')
plt.axvline(x=means[2]+dist,ls='--',color='k')
plt.axvline(x=means[2]-dist,ls='--',color='k')
#print(means[2]+0.125)
#print(means[2]-0.125)
#print(means[2]+dist)
#print(means[2]-dist)
plt.legend()
# Out:
# IceIII_3000bar/Histo_0.0625
# Liquid max: 0.5575
# IceIII max: 0.94
# Midpoint between distribitions: 0.775
# IceIII_5000bar/Histo_0.0625
# Liquid max: 0.575
# IceIII max: 0.9425
# Midpoint between distribitions: 0.78
# IceIII_2500bar/Histo_0.0625
# Liquid max: 0.5475
# IceIII max: 0.94
# Midpoint between distribitions: 0.775
# IceIII_4000bar/Histo_0.0625
# Liquid max: 0.5625
# IceIII max: 0.94
# Midpoint between distribitions: 0.7775
# Liquid max: 0.561
# IceIII max: 0.941
# Midpoint: 0.777

# %%
def func(r,r0,r1):
    y=(r-r0)/(r1-r0)
    ret=r*0
    ret[r>r0]=(y[r>r0] - 1)**2*(1 +2*y[r>r0])
    ret[r>r1]=1.0
    print(ret)
    return ret

# %%
A=np.genfromtxt('IceIII_2500bar/COLVAR_0.0550')
B=np.genfromtxt('Liquid_2500bar/COLVAR_0.0550')
B=np.array((B[:,1],B[:,1]*0)).T
A=np.array((A[:,1],A[:,1]*0+1)).T

# %%
full=np.vstack((A,B))
print(full)
# Out:
# [[0.99395  1.      ]
#  [0.869517 1.      ]
#  [0.861768 1.      ]
#  ...
#  [0.443375 0.      ]
#  [0.449899 0.      ]
#  [0.442023 0.      ]]

# %%
from scipy.optimize import curve_fit
popt, pcov = curve_fit(func, full[:,0], full[:,1],p0=[0.3,0.6])
# Out:
# [1.         1.         1.         ... 0.53310346 0.500505   0.5398474 ]
# [1.         1.         1.         ... 0.53310346 0.500505   0.5398474 ]
# [1.         1.         1.         ... 0.53310346 0.500505   0.5398474 ]
# [1.         1.         1.         ... 0.53310347 0.50050501 0.53984741]
# [1.         1.         1.         ... 0.53310348 0.50050502 0.53984742]
# [1.         1.         1.         ... 0.27028624 0.25550332 0.27337931]
# [1.         1.         1.         ... 0.27028624 0.25550332 0.27337931]
# [1.         1.         1.         ... 0.27028625 0.25550333 0.27337933]
# [1.         1.         1.         ... 0.12767173 0.12096795 0.12907863]
# [1.         1.         1.         ... 0.12767173 0.12096795 0.12907863]
# [1.         1.         1.         ... 0.12767173 0.12096796 0.12907864]
# [1.         1.         1.         ... 0.0586065  0.05558573 0.05924125]
# [1.         1.         1.         ... 0.0586065  0.05558573 0.05924126]
# [1.         1.         1.         ... 0.0586065  0.05558574 0.05924126]
# [1.         1.         1.         ... 0.02654032 0.02518563 0.02682516]
# [1.         1.         1.         ... 0.02654032 0.02518563 0.02682516]
# [1.         1.         1.         ... 0.02654032 0.02518563 0.02682516]
# [1.         1.         1.         ... 0.01193171 0.01132609 0.0120591 ]
# [1.         1.         1.         ... 0.01193171 0.01132609 0.0120591 ]
# [1.         1.         1.         ... 0.01193171 0.01132609 0.0120591 ]
# [1.         1.         1.         ... 0.00534149 0.00507129 0.00539833]
# [1.         1.         1.         ... 0.00534149 0.00507129 0.00539833]
# [1.         1.         1.         ... 0.00534149 0.00507129 0.00539833]
# [1.         1.         1.         ... 0.00238507 0.00226468 0.0024104 ]
# [1.         1.         1.         ... 0.00238507 0.00226468 0.0024104 ]
# [1.         1.         1.         ... 0.00238507 0.00226468 0.0024104 ]
# [1.         1.         1.         ... 0.00106325 0.00100965 0.00107453]
# [1.         1.         1.         ... 0.00106325 0.00100965 0.00107453]
# [1.         1.         1.         ... 0.00106325 0.00100965 0.00107453]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.73497608e-04
#  4.49650143e-04 4.78516043e-04]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.73497621e-04
#  4.49650156e-04 4.78516057e-04]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.73497646e-04
#  4.49650180e-04 4.78516082e-04]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 2.10720042e-04
#  2.00113377e-04 2.12952177e-04]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 2.10720048e-04
#  2.00113383e-04 2.12952183e-04]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 2.10720059e-04
#  2.00113394e-04 2.12952194e-04]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 9.37348597e-05
#  8.90184825e-05 9.47274278e-05]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 9.37348624e-05
#  8.90184851e-05 9.47274306e-05]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 9.37348672e-05
#  8.90184899e-05 9.47274354e-05]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.16840028e-05
#  3.95871535e-05 4.21252945e-05]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.16840040e-05
#  3.95871547e-05 4.21252958e-05]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.16840062e-05
#  3.95871568e-05 4.21252979e-05]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.85333374e-05
#  1.76012026e-05 1.87295115e-05]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.85333379e-05
#  1.76012031e-05 1.87295120e-05]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.85333389e-05
#  1.76012040e-05 1.87295130e-05]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 8.23914182e-06
#  7.82479992e-06 8.32634350e-06]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 8.23914207e-06
#  7.82480015e-06 8.32634374e-06]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 8.23914249e-06
#  7.82480057e-06 8.32634417e-06]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 3.66246701e-06
#  3.47829748e-06 3.70122719e-06]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 3.66246712e-06
#  3.47829758e-06 3.70122730e-06]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 3.66246731e-06
#  3.47829777e-06 3.70122749e-06]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.62794596e-06
#  1.54608753e-06 1.64517387e-06]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.62794601e-06
#  1.54608758e-06 1.64517392e-06]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.62794609e-06
#  1.54608766e-06 1.64517401e-06]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 7.23587903e-07
#  6.87204895e-07 7.31245080e-07]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 7.23587924e-07
#  6.87204916e-07 7.31245102e-07]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 7.23587962e-07
#  6.87204953e-07 7.31245139e-07]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 3.21610610e-07
#  3.05439912e-07 3.25013903e-07]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 3.21610619e-07
#  3.05439922e-07 3.25013913e-07]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 3.21610636e-07
#  3.05439938e-07 3.25013930e-07]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.42943128e-07
#  1.35756020e-07 1.44455732e-07]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.42943133e-07
#  1.35756024e-07 1.44455737e-07]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.42943140e-07
#  1.35756031e-07 1.44455744e-07]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 6.35318342e-08
#  6.03375277e-08 6.42041106e-08]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 6.35318361e-08
#  6.03375295e-08 6.42041125e-08]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 6.35318394e-08
#  6.03375328e-08 6.42041158e-08]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 2.82364975e-08
#  2.68167849e-08 2.85352916e-08]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 2.82364984e-08
#  2.68167857e-08 2.85352925e-08]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 2.82364998e-08
#  2.68167871e-08 2.85352940e-08]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.25496911e-08
#  1.19187053e-08 1.26824890e-08]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.25496915e-08
#  1.19187057e-08 1.26824894e-08]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.25496921e-08
#  1.19187063e-08 1.26824901e-08]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 5.57768994e-09
#  5.29725044e-09 5.63671154e-09]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 5.57769011e-09
#  5.29725060e-09 5.63671171e-09]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 5.57769040e-09
#  5.29725088e-09 5.63671200e-09]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 2.47901000e-09
#  2.35437054e-09 2.50524174e-09]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 2.47901007e-09
#  2.35437061e-09 2.50524182e-09]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 2.47901020e-09
#  2.35437074e-09 2.50524195e-09]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.10177366e-09
#  1.04637753e-09 1.11343240e-09]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.10177370e-09
#  1.04637756e-09 1.11343243e-09]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.10177375e-09
#  1.04637762e-09 1.11343249e-09]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.89683216e-10
#  4.65062776e-10 4.94864860e-10]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.89683230e-10
#  4.65062790e-10 4.94864875e-10]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.89683255e-10
#  4.65062815e-10 4.94864900e-10]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 2.17637015e-10
#  2.06694621e-10 2.19939963e-10]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 2.17637022e-10
#  2.06694628e-10 2.19939970e-10]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 2.17637033e-10
#  2.06694639e-10 2.19939981e-10]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 9.67300142e-11
#  9.18668802e-11 9.77535139e-11]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 9.67300171e-11
#  9.18668830e-11 9.77535168e-11]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 9.67300221e-11
#  9.18668879e-11 9.77535218e-11]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.29902010e-11
#  4.08287707e-11 4.34450979e-11]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.29902023e-11
#  4.08287719e-11 4.34450992e-11]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.29902045e-11
#  4.08287741e-11 4.34451014e-11]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.91056873e-11
#  1.81450464e-11 1.93078650e-11]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.91056879e-11
#  1.81450470e-11 1.93078656e-11]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.91056889e-11
#  1.81450479e-11 1.93078666e-11]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 8.48946491e-12
#  8.06248626e-12 8.57932779e-12]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 8.48946516e-12
#  8.06248650e-12 8.57932804e-12]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 8.48946560e-12
#  8.06248693e-12 8.57932848e-12]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 3.77069577e-12
#  3.58084300e-12 3.81065329e-12]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 3.77069588e-12
#  3.58084310e-12 3.81065340e-12]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 3.77069608e-12
#  3.58084329e-12 3.81065360e-12]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.67603126e-12
#  1.59165254e-12 1.69379006e-12]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.67603131e-12
#  1.59165259e-12 1.69379011e-12]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.67603139e-12
#  1.59165267e-12 1.69379020e-12]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 7.40611540e-13
#  7.02971440e-13 7.48534668e-13]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 7.40611562e-13
#  7.02971461e-13 7.48534690e-13]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 7.40611600e-13
#  7.02971499e-13 7.48534729e-13]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 3.27044769e-13
#  3.10258853e-13 3.30578710e-13]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 3.27044778e-13
#  3.10258862e-13 3.30578720e-13]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 3.27044796e-13
#  3.10258879e-13 3.30578737e-13]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.42172184e-13
#  1.34614800e-13 1.43764154e-13]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.42172189e-13
#  1.34614804e-13 1.43764159e-13]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.42172196e-13
#  1.34614811e-13 1.43764166e-13]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 6.04145831e-14
#  5.69766340e-14 6.11396433e-14]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 6.04145849e-14
#  5.69766358e-14 6.11396451e-14]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 6.04145885e-14
#  5.69766392e-14 6.11396487e-14]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 2.51984939e-14
#  2.36134709e-14 2.55334057e-14]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 2.51984946e-14
#  2.36134716e-14 2.55334064e-14]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 2.51984963e-14
#  2.36134732e-14 2.55334081e-14]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.00772103e-14
#  9.32684459e-15 1.02363433e-14]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.00772106e-14
#  9.32684488e-15 1.02363436e-14]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.00772114e-14
#  9.32684566e-15 1.02363444e-14]
# [1.0000000e+00 1.0000000e+00 1.0000000e+00 ... 3.7591359e-15 3.3909546e-15
#  3.8378090e-15]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 3.75913602e-15
#  3.39095469e-15 3.83780912e-15]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 3.75913640e-15
#  3.39095505e-15 3.83780950e-15]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.29565675e-15
#  1.11207423e-15 1.33545496e-15]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.29565678e-15
#  1.11207427e-15 1.33545499e-15]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.29565696e-15
#  1.11207443e-15 1.33545518e-15]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.16138211e-16
#  3.24880657e-16 4.36461151e-16]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.16138219e-16
#  3.24880671e-16 4.36461167e-16]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.16138321e-16
#  3.24880761e-16 4.36461263e-16]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.49215369e-16
#  1.01265677e-16 1.60311140e-16]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.38215071e-16
#  8.89129281e-17 1.49787049e-16]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.35573121e-16
#  8.59967901e-17 1.47252471e-16]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.35304979e-16
#  8.57019690e-17 1.46995072e-16]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.35278125e-16
#  8.56724560e-17 1.46969287e-16]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.35275437e-16
#  8.56695014e-17 1.46966709e-16]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.35275164e-16
#  8.56692059e-17 1.46966448e-16]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.35275137e-16
#  8.56691739e-17 1.46966420e-16]

# %%
print(popt)
# Out:
# [-4.75781267e+06  4.99410797e-01]

# %%
x=np.linspace(0,2,100)
plt.ylim([0,1])
plt.plot(x,func(x,*popt))
# Out:
# [3.30538697e-14 3.04337862e-14 2.79218774e-14 2.55181434e-14
#  2.32225842e-14 2.10351997e-14 1.89559901e-14 1.69849552e-14
#  1.51220951e-14 1.33674097e-14 1.17208991e-14 1.01825634e-14
#  8.75240237e-15 7.43041617e-15 6.21660475e-15 5.11096812e-15
#  4.11350628e-15 3.22421922e-15 2.44310695e-15 1.77016947e-15
#  1.20540678e-15 7.48818880e-16 4.00405773e-16 1.60167455e-16
#  2.81039373e-17 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00]

# %%
plt.scatter(full[:,0],full[:,1])
