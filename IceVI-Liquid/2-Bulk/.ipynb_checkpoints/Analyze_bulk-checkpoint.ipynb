# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import pickle
import MDAnalysis
from MDAnalysis.analysis import rdf
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
# Out:
# /var/folders/gk/bdqkskqj2fv8dk9kgrxm5psh0000gn/T/ipykernel_74595/2540733804.py:8: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('retina')

# %%
def extract_form_log(fn):
    lines=open(fn,'r').readlines()
    start=np.where([('Step' in l) for l in lines])[-1][0]
    data={keyi.lower(): []  for keyi in lines[start].split()}
    for l in lines[start+1:]:
        ls=l.split()
        try:
            if ls[0].isdigit():
                for i, key in enumerate(data.keys()):
                    data[key].append(float(ls[i]))
        
            else:
                break
        except:
            break
    for key in data.keys():
        data[key]=np.array(data[key])
    return data

# %%
sims=dict()
for f in glob.glob('*_*/log.lammps'):
    try:
        sims[f.replace('/log.lammps','')]=extract_form_log(f)
    except:
        pass

with open('1-bulk.pickle', 'wb') as handle:
    pickle.dump(sims, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('1-bulk.pickle', 'rb') as handle:
    sims = pickle.load(handle)
print(sims.keys())
# Out:
# dict_keys(['Liquid_6000bar', 'IceIII_4000bar', 'Liquid_7000bar', 'IceIII_5000bar', 'Liquid_4000bar', 'IceIII_6000bar', 'Liquid_5000bar', 'IceIII_7000bar', 'Liquid_2000bar', 'IceIII_2500bar', 'Liquid_3000bar', 'IceIII_2000bar', 'Liquid_2500bar', 'IceIII_3000bar'])

# %% [markdown]
# ### Volume for different pressures

# %%
NIGNORE=int(250/(2./1000)/(500))
print(NIGNORE)
plt.subplot(221)
plt.title('Liquid')
vol_liquid=[]
for key in sims.keys():
    p=float(key.replace('Liquid_','').replace('IceIII_','').replace('bar',''))
    if 'Liquid' in key:
        sim=sims[key]
        vol_liquid.append([p,np.mean(sim['volume'][NIGNORE:])])
        try:
            plt.plot(sim['step']*2/1000,sim['volume'],label=key)
        except:
            pass
plt.ylabel(r'V/Å$^3$')
plt.xlabel(r'ps')
#plt.xlim([0,100])
plt.subplot(222)
plt.title('Liquid')
vol_liquid=np.array(vol_liquid)
print(vol_liquid)
vol_liquid=vol_liquid[np.argsort(vol_liquid[:,0])]
plt.plot(vol_liquid[:,0],vol_liquid[:,1])
plt.ylabel(r'V/Å$^3$')
plt.xlabel(r'P/bar')

plt.subplot(223)
plt.title('IceIII')
vol_ice=[]
for key in sims.keys():
    p=float(key.replace('Liquid_','').replace('IceIII_','').replace('bar',''))
    if 'IceIII' in key:
        sim=sims[key]
        vol_ice.append([p,np.mean(sim['volume'][NIGNORE:])])
        try:
            plt.plot(sim['step']*2/1000,sim['volume'],label=key)
        except:
            pass
plt.ylabel(r'V/Å$^3$')
plt.xlabel(r'ps')
#plt.xlim([0,100])
plt.subplot(224)
plt.title('IceIII')
vol_ice=np.array(vol_ice)
vol_ice=vol_ice[np.argsort(vol_ice[:,0])]
plt.plot(vol_ice[:,0],vol_ice[:,1])
plt.ylabel(r'V/Å$^3$')
plt.xlabel(r'P/bar')

plt.tight_layout()
# Out:
# 250
# [[6000.         7185.7571763 ]
#  [7000.         7093.32441678]
#  [4000.         7487.43053116]
#  [5000.         7321.05759654]
#  [2000.         7965.96160519]
#  [3000.         7680.99715806]
#  [2500.         7844.92103276]]

# %% [markdown]
# ### Box sides for different pressures

# %%
sim.keys()
# Out:
# dict_keys(['step', 'temp', 'poteng', 'toteng', 'e_pair', 'e_mol', 'press', 'lx', 'ly', 'lz', 'xy', 'xz', 'yz', 'volume', 'pxx', 'pyy', 'pzz', 'pxy', 'pxz', 'pyz'])

# %%
#NIGNORE=0
plt.subplot(221)
plt.title('Liquid')
box_liquid=[]
for key in sims.keys():
    p=float(key.replace('Liquid_','').replace('IceIII_','').replace('bar',''))
    if 'Liquid' in key:
        sim=sims[key]
        plt.plot(sim['step'][NIGNORE:]*2/1000,sim['lx'][NIGNORE:])
        plt.plot(sim['step'][NIGNORE:]*2/1000,sim['ly'][NIGNORE:])
        plt.plot(sim['step'][NIGNORE:]*2/1000,sim['lz'][NIGNORE:])

        box_liquid.append([p,np.mean(sim['lx'][NIGNORE:]),
                         np.mean(sim['ly'][NIGNORE:]),
                         np.mean(sim['lz'][NIGNORE:])])
                       
plt.ylabel(r'V/Å$^3$')
plt.xlabel(r'ps')

plt.subplot(222)
plt.title('Liquid')
box_liquid=np.array(box_liquid)
box_liquid=box_liquid[np.argsort(box_liquid[:,0])]
plt.plot(box_liquid[:,0],box_liquid[:,1:4])
plt.ylabel(r'L/Å')
plt.xlabel(r'P/bar')


plt.subplot(223)
plt.title('IceIII')
box_IceIII=[]
for key in sims.keys():
    p=float(key.replace('Liquid_','').replace('IceIII_','').replace('bar',''))
    if 'IceIII' in key:
        sim=sims[key]
        plt.plot(sim['step'][NIGNORE:]*2/1000,sim['lx'][NIGNORE:])
        plt.plot(sim['step'][NIGNORE:]*2/1000,sim['ly'][NIGNORE:])
        plt.plot(sim['step'][NIGNORE:]*2/1000,sim['lz'][NIGNORE:])

        box_IceIII.append([p,np.mean(sim['lx'][NIGNORE:]),
                         np.mean(sim['ly'][NIGNORE:]),
                         np.mean(sim['lz'][NIGNORE:]),
                         np.mean(sim['xy'][NIGNORE:]),
                         np.mean(sim['xz'][NIGNORE:]),
                         np.mean(sim['yz'][NIGNORE:])])
plt.ylabel(r'V/Å$^3$')
plt.xlabel(r'ps')

plt.subplot(224)
plt.title('IceIII')
box_IceIII=np.array(box_IceIII)
box_IceIII=box_IceIII[np.argsort(box_IceIII[:,0])]
plt.plot(box_IceIII[:,0],box_IceIII[:,1:4])
plt.ylabel(r'L/Å')
plt.xlabel(r'P/bar')

plt.tight_layout()

# %%
print('Liquid')
for val in box_liquid:
    print('Pressure: ',val[0],'bar, lx:',val[1],'Å, ly:',val[2],'Å, lz:',val[3],'Å')
print()
print('IceIh')
for val in box_IceIII:
    print('Pressure: ',val[0],'bar, lx:',val[1],'Å, ly:',val[2],'Å, lz:',val[3],'Å')
# Out:
# Liquid
# Pressure:  2000.0 bar, lx: 17.697838155792276 Å, ly: 20.845715656458054 Å, lz: 21.591321235685754 Å
# Pressure:  2500.0 bar, lx: 17.607746202396804 Å, ly: 20.739599252996005 Å, lz: 21.481409262316912 Å
# Pressure:  3000.0 bar, lx: 17.484299367509987 Å, ly: 20.59419516111851 Å, lz: 21.330804374167776 Å
# Pressure:  4000.0 bar, lx: 17.336206009320904 Å, ly: 20.419760741677763 Å, lz: 21.15013082023968 Å
# Pressure:  5000.0 bar, lx: 17.206876846870838 Å, ly: 20.267428075898803 Å, lz: 20.992349568575232 Å
# Pressure:  6000.0 bar, lx: 17.100230845539283 Å, ly: 20.141813153129164 Å, lz: 20.862241651131825 Å
# Pressure:  7000.0 bar, lx: 17.02661024500666 Å, ly: 20.05509783888149 Å, lz: 20.772424725699068 Å
#
# IceIh
# Pressure:  2000.0 bar, lx: 20.132375478029292 Å, ly: 20.15684308921438 Å, lz: 20.84652149933422 Å
# Pressure:  2500.0 bar, lx: 20.109762723035953 Å, ly: 20.137171676431425 Å, lz: 20.789455139813583 Å
# Pressure:  3000.0 bar, lx: 20.087611350199733 Å, ly: 20.114386591211716 Å, lz: 20.74436149400799 Å
# Pressure:  4000.0 bar, lx: 20.045586111850866 Å, ly: 20.07564412250333 Å, lz: 20.650876993342212 Å
# Pressure:  5000.0 bar, lx: 20.00431161651132 Å, ly: 20.036049342210386 Å, lz: 20.578256311584553 Å
# Pressure:  6000.0 bar, lx: 19.962789782956058 Å, ly: 19.994842029294276 Å, lz: 20.506934161118508 Å
# Pressure:  7000.0 bar, lx: 19.925860387483354 Å, ly: 19.955720890812252 Å, lz: 20.448022463382156 Å

# %%
with open('avg_IceIII_box.dat','w') as fp_out:
    for val in box_IceIII:
        fp_out.write('{:8}{:10.5}{:10.5}{:10.5}{:10.5}{:10.5}{:10.5}\n'.format(val[0],val[1],val[2],val[3],val[4],val[5],val[6]))
# !cat avg_IceIII_box.dat
# Out:
#   2000.0    20.132    20.157    20.847  0.024126 -0.057713  0.023646
#   2500.0     20.11    20.137    20.789  0.023658 -0.060048  0.029648
#   3000.0    20.088    20.114    20.744   0.03043 -0.058771  0.023355
#   4000.0    20.046    20.076    20.651   0.02767 -0.056336   0.02315
#   5000.0    20.004    20.036    20.578  0.034788 -0.057693  0.020476
#   6000.0    19.963    19.995    20.507  0.033316 -0.057038  0.021371
#   7000.0    19.926    19.956    20.448  0.035624 -0.058758  0.021633

# %% [markdown]
# ## Plot of radial distributions for all simulations

# %%
sims_result=dict()
dr=0.05
start=500

for key in sims.keys():
    sims_result[key]=dict()
    try:
        u = MDAnalysis.Universe(key+"/water.data", key+"/dump.dcd", format="LAMMPS")
    except:
         u = MDAnalysis.Universe(key+"/iceIII.data", key+"/dump.dcd", format="LAMMPS")
    u.pbc=True
    atoms=u.select_atoms("type 2")
    RDF=rdf.InterRDF(atoms,atoms,range=(1.-.5*dr,11.+0.5*dr),nbins=1+int(10./dr)).run(start=start)
    sims_result[key]['rdf']=RDF

# %%
for key in sorted(sims_result.keys()):
    plt.plot(sims_result[key]['rdf'].results.bins,sims_result[key]['rdf'].results.rdf,label=key)
#data=np.loadtxt('rdf_rigid_1atm_300K.dat')
#plt.plot(data[:,0],data[:,1],label='ref 300K')
plt.xlabel('d/Å')
plt.ylabel('g(d)')
plt.legend(ncol=2)
plt.xlim([0,8])
# Out:
# (0.0, 8.0)
