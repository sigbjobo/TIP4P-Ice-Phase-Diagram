# %% [markdown]
# # Distribution of order parameter

# %%
import numpy as np, glob
import matplotlib.pylab as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
# Out:
# /var/folders/gk/bdqkskqj2fv8dk9kgrxm5psh0000gn/T/ipykernel_9210/1018117210.py:4: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('retina')

# %% [markdown]
# ### Overlap between distributions

# %%
data=np.loadtxt('results.txt')

plt.figure(figsize=(3.4,2))
plt.plot(data[:,0],data[:,1])
plt.xlabel(r'$\sigma$')
plt.ylabel('Overlap')
plt.tight_layout()

# %%
sigma_min=data[data[:,1]==min(data[:,1])][0][0]
print('Minimum overlap for sigma = {}'.format(sigma_min))
# Out:
# Minimum overlap for sigma = 0.065

# %% [markdown]
# ### Distributions

# %%
hist_liquid = np.loadtxt('Liquid/histo')
hist_IceV = np.loadtxt('IceIII/histo')

# %%
plt.figure(figsize=(3.4,2))
plt.plot(hist_IceV[:,0],hist_IceV[:,1])
plt.plot(hist_liquid[:,0],hist_liquid[:,1])
plt.xlim([0.3,1.3])
plt.annotate(r'$\sigma={}$'.format(sigma_min),(0.4,10))

diff_val = np.abs(hist_liquid[:,1]-hist_IceV[:,1])
diff_bin = hist_liquid[:,0]
diff_val = diff_val[(diff_bin>0.65) * (diff_bin<1.05)]
diff_bin = diff_bin[(diff_bin>0.65) * (diff_bin<1.05)]

min_order= diff_bin[diff_val.min()==diff_val]
plt.axvline(x=min_order, color='k', linestyle='--')

# %%
print('Liquid max:', hist_liquid[hist_liquid[:,1]==hist_liquid[:,1].max()][0][0])
# Out:
# Liquid max: 0.6

# %%
print('IceV max:', hist_IceV[hist_IceV[:,1]==hist_IceV[:,1].max()][0][0])
# Out:
# IceV max: 0.955

# %%
print('Midpoint between distribitions:', min_order[0])
# Out:
# Midpoint between distribitions: 1.0475

# %% [markdown]
# ## Effect of pressure on overlap

# %%
bars=set()
#overlaps=[]
for f in glob.glob('overlap*'):
    try:
        data=np.loadtxt(f)
    except:
        contin
    sigma_min=data[data[:,1]==min(data[:,1])][0][0]
    bars.add((f.split('/')[-1].replace('overlap_','').replace('.dat',''),sigma_min))
    print(f,sigma_min)
    #overlaps.append()
    plt.plot(data[:,0],data[:,1])
plt.ylim([0,0.002])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/gk/bdqkskqj2fv8dk9kgrxm5psh0000gn/T/ipykernel_9210/4156398941.py in <module>
#       2 #overlaps=[]
#       3 for f in glob.glob('overlap*'):
# ----> 4     data=np.loadtxt(f)
#       5
#       6     sigma_min=data[data[:,1]==min(data[:,1])][0][0]
#
# ~/miniforge3/lib/python3.9/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1146         # converting the data
#    1147         X = None
# -> 1148         for x in read_data(_loadtxt_chunksize):
#    1149             if X is None:
#    1150                 X = np.array(x, dtype)
#
# ~/miniforge3/lib/python3.9/site-packages/numpy/lib/npyio.py in read_data(chunk_size)
#     993             if len(vals) != N:
#     994                 line_num = i + skiprows + 1
# --> 995                 raise ValueError("Wrong number of columns at line %d"
#     996                                  % line_num)
#     997
#
# ValueError: Wrong number of columns at line 2

# %%
print(bars)
hist_liquid = np.loadtxt('Liquid/histo')
hist_IceIII = np.loadtxt('IceIII/histo')
# Out:
# {('6000bar', 0.07), ('4000bar', 0.0725), ('5000bar', 0.07), ('3500bar', 0.075)}

# %%
def remove_0(hist):
    return hist[hist[:,1]>0.001]

# %%
colors=['r','k','g','b']
for i, bar in enumerate(bars):
    #hist_liquid = np.loadtxt('Liquid_{}/Histo'.format(bar[0]))
    #hist_IceV = np.loadtxt('IceV_{}/Histo_{:.4}'.format(bar[0]))

    sig=0.06
    
    hist_IceV=np.loadtxt('IceV_{}/Histo_{:.4f}'.format(bar[0],sig))
    hist_Liquid=np.loadtxt('Liquid_{}/Histo_{:.4f}'.format(bar[0],sig))
    diff_val = np.abs(hist_Liquid[:,1]-hist_IceV[:,1])
    diff_bin = hist_liquid[:,0]
    diff_val = diff_val[(diff_bin>0.5) * (diff_bin<1.0)]
    diff_bin = diff_bin[(diff_bin>0.5) * (diff_bin<1.0)]

    hist_IceV=remove_0(hist_IceV)
    hist_Liquid=remove_0(hist_Liquid)
    print('IceV_{}/Histo_{:.4f}'.format(bar[0],bar[1]))
    print('Liquid max:', hist_Liquid[hist_Liquid[:,1]==hist_Liquid[:,1].max()][0][0])
    print('IceV max:', hist_IceV[hist_IceV[:,1]==hist_IceV[:,1].max()][0][0])
   
    min_order= diff_bin[diff_val.min()==diff_val]
    print('Midpoint between distribitions:', min_order[0])
    plt.plot(hist_IceV[:,0],hist_IceV[:,1],color=colors[i],label=bar[0])
    plt.plot(hist_Liquid[:,0],hist_Liquid[:,1],color=colors[i])
plt.xlim([0.2,1.2])
plt.legend()
# Out:
# IceV_6000bar/Histo_0.0700
# Liquid max: 0.4825
# IceV max: 0.9225
# Midpoint between distribitions: 0.6675
# IceV_4000bar/Histo_0.0725
# Liquid max: 0.4675
# IceV max: 0.92
# Midpoint between distribitions: 0.6575
# IceV_5000bar/Histo_0.0700
# Liquid max: 0.4775
# IceV max: 0.92
# Midpoint between distribitions: 0.6675
# IceV_3500bar/Histo_0.0750
# Liquid max: 0.4625
# IceV max: 0.92
# Midpoint between distribitions: 0.655
