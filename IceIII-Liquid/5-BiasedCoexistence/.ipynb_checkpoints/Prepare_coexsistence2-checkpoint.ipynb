# %% [markdown]
# # Preparation of biased coexsistence simulations

# %%
import numpy as np, sys, os, glob
import matplotlib.pylab as plt
import MDAnalysis

# %%
standard_sim=os.path.abspath('230K-3000atm')

press_box = np.genfromtxt('../BulkBox/avg_IceIII_box.dat')
presures=np.unique(press_box[:,0])

# %%
sims = dict()
for a in press_box[:]:
    fold='COEX_{}atm/{}K/'.format(a[0],a[1])
    os.system('mkdir -p {}'.format(fold))
    os.system('cp {}/* {}'.format(standard_sim,fold))
    sims[fold] = dict()
    p=a[0]
    t=a[1]
    cmd='sed -i   "s#variable .* pressure .*#variable        pressure equal {}#g" {}/in.pressure\n'.format(p,fold)
    cmd+='sed -i  \"s#variable.*temperature.*#variable        temperature equal {}#g\" {}/in.temp\n'.format(t,fold)
    cmd+='sed -i  \"s#REPLACE_TEMP#{}#g\" {}/plumed*.dat'.format(t,fold)
    os.system(cmd)
    u = MDAnalysis.Universe(fold+'/water.data', in_memory=True)
    print('before',u.dimensions)

    lx=a[2]
    ly=a[3]
    lz=a[4]
    xy=a[5]
    xz=a[6]
    yz=a[7]
    A=np.array([[lx,0,0],
                 [xy,ly,0],
                 [xz,yz,lz]])
    dimensions_new=MDAnalysis.lib.mdamath.triclinic_box(A[0], A[1], A[2])
   
    max_l=np.max(u.dimensions[:3])
    max_dim=np.where(u.dimensions==max_l)[0][0]
    dimensions_new[max_dim]=u.dimensions[max_dim]
    #print('after',dimensions_new)
    for dim in range(3):
        if not dim==max_dim:
            u.coord.positions[:,dim] = u.coord.positions[:,dim]*dimensions_new[dim]/u.dimensions[dim]
    u.dimensions=dimensions_new
    print('after',u.dimensions)

    u.atoms.write(fold+'/water.data')
# Out:
# mkdir: COEX_2000.0atm: No such file or directory
# cp: directory COEX_2000.0atm/270.0K does not exist
# sed: 1: "COEX_2000.0atm/270.0K// ...": invalid command code C
# sed: 1: "COEX_2000.0atm/270.0K// ...": invalid command code C
# sed: 1: "COEX_2000.0atm/270.0K// ...": invalid command code C
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /var/folders/gk/bdqkskqj2fv8dk9kgrxm5psh0000gn/T/ipykernel_74408/3672997540.py in <module>
#      12     os.system(cmd)
# ---> 13     u = MDAnalysis.Universe(fold+'/water.data', in_memory=True)
#      14     print('before',u.dimensions)
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/core/universe.py in __init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, in_memory, in_memory_step, *coordinates, **kwargs)
#     335             self.filename = _check_file_like(topology)
# --> 336             topology = _topology_from_file_like(self.filename,
#     337                                                 topology_format=topology_format,
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/core/universe.py in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     129             # Runs if the error is propagated due to no permission / file not found
# --> 130             raise sys.exc_info()[1] from err
#     131         else:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/core/universe.py in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     121         with parser(topology_file) as p:
# --> 122             topology = p.parse(**kwargs)
#     123     except (IOError, OSError) as err:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/topology/LAMMPSParser.py in parse(self, **kwargs)
#     269
# --> 270         head, sects = self.grab_datafile()
#     271
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/topology/LAMMPSParser.py in grab_datafile(self)
#     201         """
# --> 202         f = list(self.iterdata())
#     203
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/topology/LAMMPSParser.py in iterdata(self)
#     187     def iterdata(self):
# --> 188         with openany(self.filename) as f:
#     189             for line in f:
#
# ~/miniforge3/lib/python3.9/contextlib.py in __enter__(self)
#     116         try:
# --> 117             return next(self.gen)
#     118         except StopIteration:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/util.py in openany(datasource, mode, reset)
#     314     """
# --> 315     stream = anyopen(datasource, mode=mode, reset=reset)
#     316     try:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/util.py in anyopen(datasource, mode, reset)
#     393                 openfunc = read_handlers[ext]
# --> 394                 stream = _get_stream(datasource, openfunc, mode=mode)
#     395                 if stream is not None:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/util.py in _get_stream(filename, openfunction, mode)
#     435         if errno.errorcode[err.errno] in ['ENOENT', 'EACCES']:
# --> 436             raise sys.exc_info()[1] from err
#     437         return None
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/util.py in _get_stream(filename, openfunction, mode)
#     429     try:
# --> 430         stream = openfunction(filename, mode=mode)
#     431     except (IOError, OSError) as err:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py in bz2_pickle_open(name, mode)
#     477     bz_mode = mode.replace("t", "")
# --> 478     binary_file = BZ2Picklable(name, bz_mode)
#     479     if "t" in mode:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py in __init__(self, name, mode)
#     265         self._bz_mode = mode
# --> 266         super().__init__(name, mode)
#     267
#
# ~/miniforge3/lib/python3.9/bz2.py in __init__(self, filename, mode, compresslevel)
#      84         if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 85             self._fp = _builtin_open(filename, mode)
#      86             self._closefp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'COEX_2000.0atm/270.0K//water.data'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /var/folders/gk/bdqkskqj2fv8dk9kgrxm5psh0000gn/T/ipykernel_74408/3672997540.py in <module>
#      12     os.system(cmd)
# ---> 13     u = MDAnalysis.Universe(fold+'/water.data', in_memory=True)
#      14     print('before',u.dimensions)
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/core/universe.py in __init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, in_memory, in_memory_step, *coordinates, **kwargs)
#     335             self.filename = _check_file_like(topology)
# --> 336             topology = _topology_from_file_like(self.filename,
#     337                                                 topology_format=topology_format,
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/core/universe.py in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     129             # Runs if the error is propagated due to no permission / file not found
# --> 130             raise sys.exc_info()[1] from err
#     131         else:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/core/universe.py in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     121         with parser(topology_file) as p:
# --> 122             topology = p.parse(**kwargs)
#     123     except (IOError, OSError) as err:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/topology/LAMMPSParser.py in parse(self, **kwargs)
#     269
# --> 270         head, sects = self.grab_datafile()
#     271
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/topology/LAMMPSParser.py in grab_datafile(self)
#     201         """
# --> 202         f = list(self.iterdata())
#     203
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/topology/LAMMPSParser.py in iterdata(self)
#     187     def iterdata(self):
# --> 188         with openany(self.filename) as f:
#     189             for line in f:
#
# ~/miniforge3/lib/python3.9/contextlib.py in __enter__(self)
#     116         try:
# --> 117             return next(self.gen)
#     118         except StopIteration:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/util.py in openany(datasource, mode, reset)
#     314     """
# --> 315     stream = anyopen(datasource, mode=mode, reset=reset)
#     316     try:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/util.py in anyopen(datasource, mode, reset)
#     393                 openfunc = read_handlers[ext]
# --> 394                 stream = _get_stream(datasource, openfunc, mode=mode)
#     395                 if stream is not None:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/util.py in _get_stream(filename, openfunction, mode)
#     435         if errno.errorcode[err.errno] in ['ENOENT', 'EACCES']:
# --> 436             raise sys.exc_info()[1] from err
#     437         return None
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/util.py in _get_stream(filename, openfunction, mode)
#     429     try:
# --> 430         stream = openfunction(filename, mode=mode)
#     431     except (IOError, OSError) as err:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py in bz2_pickle_open(name, mode)
#     477     bz_mode = mode.replace("t", "")
# --> 478     binary_file = BZ2Picklable(name, bz_mode)
#     479     if "t" in mode:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py in __init__(self, name, mode)
#     265         self._bz_mode = mode
# --> 266         super().__init__(name, mode)
#     267
#
# ~/miniforge3/lib/python3.9/bz2.py in __init__(self, filename, mode, compresslevel)
#      84         if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 85             self._fp = _builtin_open(filename, mode)
#      86             self._closefp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'COEX_2000.0atm/270.0K//water.data'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/gk/bdqkskqj2fv8dk9kgrxm5psh0000gn/T/ipykernel_74408/3672997540.py in <module>
#      11     cmd+='sed -i  \"s#TEMP=230#TEMP={}#g\" {}/plumed*.dat'.format(t,fold)
#      12     os.system(cmd)
# ---> 13     u = MDAnalysis.Universe(fold+'/water.data', in_memory=True)
#      14     print('before',u.dimensions)
#      15
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/core/universe.py in __init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, in_memory, in_memory_step, *coordinates, **kwargs)
#     334         if not isinstance(topology, Topology) and not topology is None:
#     335             self.filename = _check_file_like(topology)
# --> 336             topology = _topology_from_file_like(self.filename,
#     337                                                 topology_format=topology_format,
#     338                                                 **kwargs)
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/core/universe.py in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     128             errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     129             # Runs if the error is propagated due to no permission / file not found
# --> 130             raise sys.exc_info()[1] from err
#     131         else:
#     132             # Runs when the parser fails
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/core/universe.py in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     120     try:
#     121         with parser(topology_file) as p:
# --> 122             topology = p.parse(**kwargs)
#     123     except (IOError, OSError) as err:
#     124         # There are 2 kinds of errors that might be raised here:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/topology/LAMMPSParser.py in parse(self, **kwargs)
#     268             self.style_dict = None
#     269
# --> 270         head, sects = self.grab_datafile()
#     271
#     272         try:
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/topology/LAMMPSParser.py in grab_datafile(self)
#     200         sections - dict of section name: content
#     201         """
# --> 202         f = list(self.iterdata())
#     203
#     204         starts = [i for i, line in enumerate(f)
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/topology/LAMMPSParser.py in iterdata(self)
#     186
#     187     def iterdata(self):
# --> 188         with openany(self.filename) as f:
#     189             for line in f:
#     190                 line = line.partition('#')[0].strip()
#
# ~/miniforge3/lib/python3.9/contextlib.py in __enter__(self)
#     115         del self.args, self.kwds, self.func
#     116         try:
# --> 117             return next(self.gen)
#     118         except StopIteration:
#     119             raise RuntimeError("generator didn't yield") from None
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/util.py in openany(datasource, mode, reset)
#     313     :func:`anyopen`
#     314     """
# --> 315     stream = anyopen(datasource, mode=mode, reset=reset)
#     316     try:
#     317         yield stream
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/util.py in anyopen(datasource, mode, reset)
#     392             for ext in ('bz2', 'gz', ''):  # file == '' should be last
#     393                 openfunc = read_handlers[ext]
# --> 394                 stream = _get_stream(datasource, openfunc, mode=mode)
#     395                 if stream is not None:
#     396                     break
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/util.py in _get_stream(filename, openfunction, mode)
#     434         # either the file isn't there or the permissions don't allow access.
#     435         if errno.errorcode[err.errno] in ['ENOENT', 'EACCES']:
# --> 436             raise sys.exc_info()[1] from err
#     437         return None
#     438     if mode.startswith('r'):
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/util.py in _get_stream(filename, openfunction, mode)
#     428     """Return open stream if *filename* can be opened with *openfunction* or else ``None``."""
#     429     try:
# --> 430         stream = openfunction(filename, mode=mode)
#     431     except (IOError, OSError) as err:
#     432         # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py in bz2_pickle_open(name, mode)
#     476                          "files can be pickled.")
#     477     bz_mode = mode.replace("t", "")
# --> 478     binary_file = BZ2Picklable(name, bz_mode)
#     479     if "t" in mode:
#     480         return TextIOPicklable(binary_file)
#
# ~/miniforge3/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py in __init__(self, name, mode)
#     264     def __init__(self, name, mode='rb'):
#     265         self._bz_mode = mode
# --> 266         super().__init__(name, mode)
#     267
#     268     def __getstate__(self):
#
# ~/miniforge3/lib/python3.9/bz2.py in __init__(self, filename, mode, compresslevel)
#      83
#      84         if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 85             self._fp = _builtin_open(filename, mode)
#      86             self._closefp = True
#      87             self._mode = mode_code
#
# FileNotFoundError: [Errno 2] No such file or directory: 'COEX_2000.0atm/270.0K//water.data'

# %% [markdown]
# ### Convert notebook to python script

# %%
# !jupyter nbconvert --to script Prepare_coexsistence2.ipynb
# Out:
# [NbConvertApp] Converting notebook Prepare_coexsistence2.ipynb to script
# [NbConvertApp] Writing 1825 bytes to Prepare_coexsistence2.py
